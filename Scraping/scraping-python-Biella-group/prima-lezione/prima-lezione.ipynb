# %%
from bs4 import BeautifulSoup
import requests
import collections
collections.Callable = collections.abc.Callable

# %%
req = requests.get("https://www.corriere.it")

# %%
print(req.status_code)
# Out:
# 200

# %%
req.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '117563', 'Cache-Control': 'max-age=10,public', 'Edge-Control': '!no-store, max-age=10', 'X-RCS-CacheZone': 'cache-client', 'Access-Control-Allow-Origin': '*', 'Content-Type': 'text/html; charset=ISO-8859-1', 'Content-Encoding': 'gzip', 'Referrer-Policy': 'no-referrer-when-downgrade', 'Via': '1.1 varnish, 1.1 varnish', 'X-Unique-Id': 'd991e10d-2416-4c54-a1c7-1b20f0d1bb9e, 877a1c5c-5456-4ed3-b205-14333f82e25e', 'Accept-Ranges': 'bytes', 'Date': 'Fri, 12 Jan 2024 23:57:15 GMT', 'Age': '5', 'X-Served-By': 'cache-ams21040-AMS, cache-mxp6936-MXP', 'X-Cache': 'MISS, HIT', 'X-Cache-Hits': '2, 5', 'X-Timer': 'S1705103835.098632,VS0,VE0', 'Vary': 'Accept-Encoding'}

# %%
soup = BeautifulSoup(req.text, "html.parser")

# %%
h4s = soup.find_all("h4")

# %%
h4s[0].attr

# %%
h4s[0].content

# %%
h4s[0].get_text()
# Out:
# 'Più popolari'

# %%
for titoli in h4s:
    print(titoli.get_text())
# Out:
# Più popolari
# In evidenza
# Cook
# Cronache
# Podcast
# Dizionari
# Opinioni
# Economia
# LOGIN: TECNOLOGIA E INNOVAZIONE
# Spettacoli
# Cook
# Salute
# Sport
# Motori
# Politica
# Esteri
# Cultura
# Scuola
# La27ora
# Moda
# Animali
# Magazine
# Video - Corriere TV
# Meteo
# Oroscopo
# Gaza, 100 giorni di guerra di Battistini, Cremonesi, Fontana, Frattini, Natale
# Il direttore Fontana: ‘L’escalation e  i segnali del governo italiano’
# Frana in Valsugana, il masso occupa un'intera carreggiata
# Accoltellata sul bus a Milano: un passeggero tenta invano di difenderla
#  Biden pronto a nuovi attacchi agli Houti Tajani: «L’Italia non può partecipare, serve un voto del Parlamento |      Chi sono i ribelli
# DOMANDE E RISPOSTE Chi sono gli Houthi e cosa faranno adesso? Che ruolo ha l’Iran?
# L’ANALISI I costi della crisi del mar Rosso.   Da lì passa il 40% del commercio italiano via nave
# IL PERSONAGGIO Barak, il giudice di Israele, sfuggito ai nazisti, liberal, nemico di Netanyahu
# Le folle ai comizi sfidano Pechino. L’esercito cinese a Taiwan: «Schiacceremo i complotti indipendentisti»
# Sequestrato a Sgarbi il quadro di Manetti. Il sottosegretario: «L’ho consegnato io»
# Come ristrutturare casa senza superbonus: ecco le agevolazioni più convenienti del 2024Abitazioni di lusso a Milano, rincari del 7,1%
# Regionali in Sardegna, centrodestra senza pace. FdI: corre Truzzu. Solinas: anch’io
# Acca Larenzia, dopo le polemiche del 7 gennaio Casapound diffonde il video della giornata
# Attraversa con lo scooter i binari della Circumvesuviana, ragazzo ucciso da treno in transito
# Milano, donna accoltellata sull'autobus e lasciata in fin di vita: l’ex arrestato per tentato omicidio e stalking
# Condannata a tredici anni la vivandiera di Messina Denaro: «Aiutò il boss e l’organizzazione»
# Il supertestimone, la traccia di sangue,  la pista alternativa: la strage  di Erba ai raggi X
# Dopo la rabbia, le scuse. Bianca Berlinguer ora elogia la sua redazione: «Fa un lavoro ottimo e prezioso»
# Iowa, testa a testa tra Nikki Haley e Ron DeSantis: primo test per scegliere  sfidante di Trump
# Benedizione ai gay, i vescovi africani: «Ci si espone a scandali». Ma il papa  non fa retromarcia
# Francesca  (alla ricerca di una casa) e la vita con il cane gigante: «Rifiuta la cuccia e divora panettoni»
# Indagando la lingua dell’odio: «la Lettura» è già nell’App (ancora in promozione)
# Il regista di «Parasite» chiede giustizia per l'attore Lee Sun-kyun: «Inchiesta sulla morte»
# Paramount ipotesi fusione con Skydance: Ellison pronto a comprare (in contanti)
#  Bollette gas, aumenti a 177 euro per chi non ha scelto nuovi operatori ed è senza tutela
# Burberry taglia le stime e crolla in Borsa: la frenata del lusso (ma Cucinelli corre)
# Hertz vende 20 mila auto elettriche e torna al diesel: costi alti e domanda debole
# Tesla, stop alla produzione in Germania per la crisi di Suez: mancano componenti
# La balena più rara del mondo è stata filmata per la seconda volta nella storia
# Lo sketch  sulla Natività «blasfemo e volgare», Gasparri contro i comici  Paolantoni e Izzo
# Il concorrente di Masterchef e il problema di matematica, Cannavacciuolo s’infuria: «Svengo!»
# Il Parco nazionale di Yosemite innevato è come un mondo incantato: il video
# Usa, attivista climatico sale sul palco del candidato DeSantis: placcato dalla sicurezza
# Acca Larentia, la tv russa critica con l’Italia: «L'Europa torna al nazismo»
# Nanoplastiche: in una bottiglia d’acqua in media sono 240mila. Quali effetti sulla salute?
# Il tumore al pancreas che ha colpito Eriksson:  cos’è e come si può scoprire precocemente
# La piccola isola che sfida la Cina (all’ombra di Hong Kong)
# Il Grande Anello sfida la teoria che governa l’Universo. Gli scienziati: inspiegabile
# Recensione choc contro la pizzeria: «Mi hanno messo vicino a gay e disabili». La titolare: «Eviti il mio locale»
# Nordio nega l’estradizione di don Franco Reverberi, accusato di torture e omicidio in Argentina
# Val Pusteria, turista tedesca di 16 anni cade nel dirupo: trovata morta dopo ore
# L’aggressione alle spalle, in 15 minuti Così Ester Palmieri è stata uccisa dal suo exIl nuovo lavoro, i 3 figli: chi era la vittima
# Il suo ex agli Esteri, la “pupilla” di Sarkozy alla Cultura: le polemiche sul nuovo governo di Attal
#  Usa consultano la Cina per evitare tensioni dopo le elezioni di Taiwan. Pechino: «Fate la scelta giusta»
# Piranesi, polemista inquietonel  libro di Pierluigi Panza
# Hopper e le sue tante solitudini: perché sono una fotografia del mondo di oggi
# L’impunità dell’aggressore della porta a fianco
# C’è un nuovo re in Danimarca: ma hanno ancora senso le monarchie?
#
# L'audio del Var durante Inter-Verona: «Fischia, santo cielo!»
#
#
# Acca Larenzia, la tv russa critica  l’Italia: «L'Europa torna al nazismo»
#
#
# Dalle tv trasparenti alle supercar-volanti: le otto innovazioni che hanno stupito di più al Ces di Las Vegas
#
#
# EDITORIALI COMMENTI
#
# La cabina di regia del caos e il bene collettivo
# Contro i femminicidi: la sindrome degli annunci
# Il caso pandoro e l’impegno alla serietà
#  Micael Dahlén, lezioni di felicità
# Inter-Verona, cosa dice il Var e perché l’arbitro non l’ha ascoltato: «Questa è  furbizia»
# Schumacher, si sposa la figlia Gina: i dubbi sulla presenza di Michael. Cosa sappiamo
# «Saltburn», necrofilia e sesso estremo: il film che divide l’Inghilterra
# Tananai e la foto in sovrappeso ritoccata: «Devo tornare in forma per Sanremo». Lo accusano  di grassofobia
# La madre litiga con Mbappé: «Troppi soldi in beneficenza. A me il 30%, sennò lo lascio»
# È stata la sua unica auto per 58 anni: l'appello di nonna Pina per riavere la Fiat 500 rubata
# MasterChef 13, le pagelle: Alberto (voto 9), Kassandra (3), Barbieri pompiere (6.5)
# Nedved e le due case tra Italia e Repubblica Ceca: cosa fa adesso l’ex giocatore della Juventus
# Julia Roberts: «Non volevo fare Notting Hill, era imbarazzante interpretare un’attrice»
# Maddalena Corvaglia: la fine dell’amicizia con Canalis, il flirt con Morgan e altri segreti
# Gli ascolti tv dell’11 gennaio: Doc sbaraglia tutti, poi  Terra Amara e Juventus-Frosinone
# Calciomercato: Napoli, c’è l’accordo per Traoré. Lazio su Neuhaus. Milan-Matic Diretta
#  L’oroscopo di Paolo Fox di oggi: amore, lavoro, benessere e fortuna, segno per segno
# IL BELLO DELL'ITALIA
# Il «canto di Palermo» di Sasha Vinci, dove lo skyline diventa musica
# Ultima estrazione del Lotto, SuperEnalotto e 10eLotto serale
# MILANO
#
# Smog, la Regione: «Nel 2023 è migliorata la qualità dell'aria in Lombardia». Ma 6 città superano ancora il limite di «giorni neri»
#
# San Donato Milanese, accoltellamento fuori da scuola tra due studenti 16enni: un ferito grave
#
# Bambino con la sindrome di Down insultato e sfiorato mentre attraversa la strada: «Caro automobilista, fa male l’indifferenza»
#
# Pao, lo street artist milanese dei pinguini sui paracarri e dei murales: «Milano non è più a servizio di chi la vive»
# ROMA
#
# Roma, un anno fa moriva Lorenzo Moi, investito dopo il ricovero. I genitori a piazzale Clodio: «Verità per Lollo»
#
# Tivoli, violenze sessuali sulla figlia di 10 anni: arrestato 46enne dopo la denuncia dell'ex moglie
#
# Domenica ecologica, tutte le restrizioni in vigore il 14 gennaio: gli orari, gli obblighi e le deroghe
#
# Ecco Francesca Giubelli, affascinante influencer virtuale creata dall'intelligenza artificiale Video
# TORINO
#
# Marcello Gandini si laurea a 85 anni. «Mio padre mi voleva pianista, io ho fatto suonare i motori delle Lamborghini» -  Foto
#
# I vertici Lear agli operai: «A Torino c’è solo Cassa integrazione, il lavoro è in Francia: venite lì»
#
# I fondatori di Italian Elite: «Partiti con 600 euro a testa, ora fatturiamo un milione di euro»
#
# Il computer più antico? È la «Macchina Plana» (e si può vedere in via Garibaldi)
# EDIZIONI LOCALI
#
# Il re delle cravatte Marinella diffida la figlia dell'ex boss Giuliano: «Non le accosti al profumo "'O Liò"»
#
# Frana sulla Valsugana, pioggia di massi giganti: strade e ferrovia chiuse
#
# Con il furgone in Ztl per 1000 volte in un anno: 80mila euro di multe da pagare
#
# Cesare Cremonini e la foto del 2016 dove pesava cento chili: «Stavo male»
#
# La mamma arrestata per l'omicidio di Alice e Mattia trasferita in carcere
#
# Fuori dalla sala d’attesa e niente ricette. Medico nella bufera, a Bagolino arrivano i carabinieri
# ESTERI
# La signora del giardino più brutto del mondo America-Cina di oggi
# Polonia, arrestato l’ex ministro dell’Interno, Duda: «Lo libererò»
# New York, spunta un tunnel sotto la sinagoga: scontri ortodossi-polizia
# «Netanyahu feels  that there is a good chance that Trump will be reelected. He doesn’t really have to listen to Biden»
# SPETTACOLI
# «Sex and the City» show, Candace Bushnell: vi racconto com’è nata la serie tv
# «I Fantastici 5»: un romanzo di formazione, una storia di coraggio
# Il punto di forza di «Doc - Nelle tue mani»? Non ha ambizioni autoriali
# Si prese a pugni con Axl Rose, quando ridicolizzò Celentano: i 5 personaggi che David Bowie non poteva sopportare
# SPORT
# Inter-Verona, l’audio. Cosa dice il Var e perché l’arbitro Fabbri non l’ha ascoltato: «Questa è furbizia»
# Gli arbitri rivelano gli 8 errori del girone di andata: chi ci ha perso di più fra Inter e Juve?
# Nedved e le due case in due Paesi: cosa fa adesso l’ex giocatore della Juventus
# La tv oscura Milwaukee-Boston e cambia partita: troppo poche emozioni e punteggio deciso
# Il Papa ai borsisti del Toniolo: giovani, passione e impegno, «antidoti al pensiero breve»
# Pellegrino con una sedia a rotelle vuota: «Parlo di disabilità, e porto mia mamma sempre con me»
# Federica: «Grazie al nidosono una madre serena e ritorno a lavorare»|Video
# Dopo 65 anni ritrovail portafoglio della mammaperso in un cinema
# Come perdere qualche chilo in 4 settimane? Con 5 pasti al giorno. Ecco perché (e come)
# Dallo “shullet” al “layer bob”, i nuovi tagli di capelli del 2024 e a chi stanno bene
# La vita è più dolce, con questi 20 morbidi maglioni a collo alto in saldo | Foto
# Il 2024 che anno sarà in amore? Lo troveremo? Le previsioni
#
# Mark Zuckerberg annuncia il nuovo progetto: «Alleverò bovini che mangeranno solo noci e berranno birra»
#
# Lo schermo ma c'è ma non si vede: Samsung e Lg inventano i tv trasparenti
#
# La prova di Nuance Audio, gli occhiali che fanno «sentire» meglio
#
# Blockchain e intelligenza artificiale: se anche l'auto diventa uno «smart device» Il caso della turca Togg
#
# Stanley Cup, perché questa borraccia termica è soldout ovunque (ed è il prodotto del momento sui social)
#
# Levapelucchi per maglioni, maglie e sciarpe invernali: quali comprare e perché
#
# Cos'è una Power Station: il nuovo gadget tech di cui tutti avremo bisogno
#
# Poco cala il tris: i nuovi smartphone X6, X6 Pro ed M6 Pro costano «poco» ma offrono tanto
# POLITICA
# Toti: «Giusto candidare gli uscenti. Non si usino i territori per i rapporti di forza romani»
# Europee, Gentiloni e Conte non si candidano. Il leader M5S: «Nessun leader lo faccia, compresa Schlein»
# Le missioni di Crippa, il «guastatore» del segretario Salvini
# IL SONDAGGIOAumentano i «fronti» di inquietudine: balzo di sanità immigrazione e sicurezza
# ANIMALI E AMBIENTE
# Svolta in Corea del Sud: il Parlamento  vota lo stop al commercio di carne di cane
# Scoperto in Kenya il primo elefante maschio nato senza zanne: la natura si difende così dal bracconaggio?
# Palermo: cane legato a un palo e bruciato, denunciato il proprietario. Brambilla: «Servono pene più severe»
# Il barboncino Chico nominato ambasciatore digitale delle Olimpiadi di Milano Cortina
# Perché Jeremy A. White in boxer (griffati) è il fidanzato immaginario che ci meritiamo
# I vini memorabili del 2023 secondo il New York Times (ci sono anche due italiani)
# Questi cibi aiutano a non ingrassare: la spiegazione in uno studio olandese
# Doggy bag obbligatoria nei ristoranti, gli chef divisi: «Ideale» o «anacronistica»?
# Lavoro e pensioni, dai fringe benefit ai calcoli di Quota 103: tutte le novità del 2024
# Bollette, Enel ed Hera fanno il pieno all’asta del mercato tutelato: 7 lotti (1,5 milioni di clienti) ciascuno
# Luce, gas e fibra in un unico contratto, perché conviene ai consumatori?
#  Google licenzierà centinaia di dipendenti: tagli agli sviluppatori di assistenti vocali e realtà aumentata
# Milano come tanti non l’hanno mai vista: l’omaggio di De Biasi alla sua città d’adozione
# Sara Lazzaro: «L’Agnese di Doc, una donna di potere ma così imperfetta»
# Matteo Branciamore: «Io un bravo ragazzo? No, un cattivo senza sentimenti»
# Saviano: «La rettifica di CasaPound sulle mie parole e la favola di Terence Hill»
# SCUOLA
# «Quote blu» a scuola, basta ipocrisie: docenti pagati poco perché in maggioranza donne
# Gherardo Colombo, Laura Pigozzi e Andrea Staid insieme per la scuola
# «Non sparate sulla scuola», il 15 e il 16 gennaio incontro a Prato e a Novara
# Arbitro: un risolutore obiettivo che è sempre contestato
# L’influenza di quest’anno è molto aggressiva o solo più contagiosa? Cosa sapere
# L’enzima che metabolizza l’alcol combatte anche l’influenza, ma è dei sobri
# La dieta ideale per perdere peso dopo le feste (senza mettere a rischio la salute)
# Malattie infettive, per quanto si rimane contagiosi? Sintomi e cura
#  Sony Honda Mobility: le auto saranno uno spazio creativo con film, musica e videogiochi
# L’auto ibrida consuma troppo? Ecco tutti i semplici trucchi per risparmiare
# Volkswagen introduce ChatGPT sulle sue auto e mostra  la nuova Golf
# Dalla Panda (rivoluzionata) all’Alfa Romeo Milano, 15 auto che vedremo nel 2024
# A scuola con l’App de «la Lettura» (in offerta fino al 31 gennaio)
# «La Lettura»: nella newsletter l’anteprima di Daniele Mencarelli
# Sulla soglia delle identitàL’estratto del libro postumo di Michela Murgia
# Massimiliano Fuksas compie 80 anni: «La mia città surrealista»
# BLOG
#
#
#  RUBRICHE
#
#
# Moto d'epoca ferma nel box? RCA obbligatoria Gran confusione grazie a una ...
#
#
# Capodanno con pistola
#
#
# TG1 e TG2
#
#
# La favolaccia di Enea e il sushi di Castellitto jr
#
#
# Un'attivista iraniana rifugiata in Turchia ha bisogno di un trapianto di ...
#
#
# Crollo Milan, #Pioliout e il Dna scomparso
#
#
# Il passero su due fili
#
#
# Nel 1987, le prime convulsioni e il ricovero in Neurologia. La diagnosi: ...
#
#
# Inclusione a scuola, perché bisogna attenuare la differenza tra ...
#
#
# Torna Pitigrilli, re del paradosso. In letteratura e nella vita
#
#
# Marina  Cvetaeva: "La via delle comete" è  la nuova antologia delle ...
#
#
# Fortnite contro Apple: il Project Liberty di Tim Sweeney
#
#
# Le diagnosi di cancro sono devastanti!!! ( il generale Austin)
#
#
# Dalle tv trasparenti alle supercar-volanti: le otto innovazioni che hanno stupito di più alla fiera tecnologica di Las Vegas
#
#
# Cuccioli di cane e di ghepardo giocano insieme: il video è tenerissimo
#
#
# Sulmona, il lupo passeggia nel centro abitato
#
#
# Sicilia, donna porta al guinzaglio una gallina: il video
#
#
# Avete mai visto un maniscalco al lavoro?
#
#
# L'espressione del Labrador Pippo è un meme di internet
#
# Addio skinny. La tendenza jeans 2022 è soprattutto comoda.  I modelli
# Cosa mettere sulla parete dietro al divano per aggiungere personalità al soggiorno | Foto
# Best in travel 2024: le 50 mete top per Lonely Planet  LE FOTO
# Le 30 fotografie più belle del mondo FOTO
# Coppia: consigli e curiosità per vivere una relazione appagante e duratura
# Legal Talk – Il Futuro della Professione Legale - 13 Dicembre. Iscriviti subito.
# I più visti
#
# Le tappe giudiziarie della strage di Erba
#
#
# Doggy bag obbligatoria per i ristoratori contro gli sprechi, la proposta di legge
#
#
# Tiberio Timperi scivola sulla cera e cade in diretta tv a ?I Fatti Vostri'
#
#
# Tutto sul Festival di Sanremo: le date, i big in gara, gli ospiti e i costi dei biglietti
#
# I più letti
# I BLOG DEL CORRIERE
